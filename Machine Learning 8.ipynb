# %% [markdown]
# In this assignment students have to find the frequency of words in a webpage. User can use urllib and BeautifulSoup to extract text from webpage.
# Hint:
# from bs4 import BeautifulSoup
# import urllib.request
# import nltk
# response = urllib.request.urlopen('http://php.net/')
# html = response.read()
# soup = BeautifulSoup(html,"html5lib")

# %%
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation
import urllib.request
import nltk

# %%
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/Twenty_One_Pilots')
html = response.read()
soup = BeautifulSoup(html,"html5lib")

# %%
text = (''.join(s.findAll(text=True))for s in soup.findAll('a'))

c = Counter((x.rstrip(punctuation).lower() for y in text for x in y.split()))
# Print most common words
print (c.most_common())
# Out:
# [('', 222), ('one', 187), ('pilots', 184), ('"twenty', 104), ('twenty', 79), ('the', 79), ('a', 52), ('in', 39), ('and', 37), ('of', 35), ('b', 35), ('tour', 34), ('to', 32), ('on', 28), ('with', 28), ('rock', 26), ('music', 26), ('at', 25), ('new', 25), ('[151', 25), ('for', 24), ('album', 23), ('out', 18), ('awards', 15), ('billboard', 15), ('c', 15), ('wikipedia', 15), ('best', 14), ('[152', 14), ('original', 14), ('video', 14), ('ohio', 13), ('joseph', 13), ('blurryface', 13), ('[150', 13), ('from', 13), ('by', 12), ('tyler', 12), ('band', 12), ('songs', 12), ('my', 12), ('live', 12), ('alternative', 11), ('vessel', 11), ('[190', 11), ('articles', 11), ('columbus', 10), ('pop', 10), ('[185', 10), ('1', 9), ('gold', 9), ('d', 9), ('e', 9), ('"the', 9), ('their', 9), ('josh', 8), ('dun', 8), ('trench', 8), ('world', 8), ('arena', 8), ('release', 8), ('announce', 8), ('grammy', 7), ('regional', 7), ('radio', 7), ('you', 7), ('hot', 7), ('emotional', 7), ('roadshow', 7), ('american', 7), ('blood', 7), ('[168', 7), ('show', 7), ('song', 7), ('list', 7), ("'blurryface", 7), ('chris', 7), ('about', 7), ('identifiers', 7), ('hip', 6), ('hop', 6), ('indie', 6), ('rap', 6), ('fueled', 6), ('ramen', 6), ('stressed', 6), ('sleep', 6), ('night', 6), ('squad', 6), ('niners', 6), ('london', 6), ('bandito', 6), ('talk', 6), ('first', 6), ('"interview', 6), ('fans', 6), ('perform', 6), ('watch', 6), ('dates', 6), ('"hear', 6), ('are', 6), ('f', 6), ('g', 6), ('groups', 6), ('award', 5), ('performance', 5), ('history', 5), ('discography', 5), ('[5', 5), ('come', 5), ('hands', 5), ('holding', 5), ('boy', 5), ('2016', 5), ('k', 5), ('[184', 5), ('part', 5), ('salih', 5), ('up', 5), ('that', 5), ('single', 5), ('"watch', 5), ('h', 5), ('i', 5), ('j', 5), ('biggest', 5), ('heathens', 4), ('america', 4), ('musical', 4), ('links', 4), ('university', 4), ('o', 4), ('house', 4), ('youtube', 4), ('car', 4), ('guns', 4), ('200', 4), ('100', 4), ('fall', 4), ('mtv', 4), ('tear', 4), ('heart', 4), ('mutemath', 4), ('suicide', 4), ('chemical', 4), ('theatre', 4), ('nationwide', 4), ('press', 4), ('riaa', 4), ('[178', 4), ('chart', 4), ('every', 4), ('off', 4), ('"tyler', 4), ('we', 4), ('twitter', 4), ('this', 4), ('complete', 4), ('reddit', 4), ('just', 4), ("'my", 4), ('lounge', 4), ('review', 4), ('–', 4), ('pages', 4), ('page', 4), ('(album', 3), ('electropop', 3), ('all', 3), ('ride', 3), ('duo/group', 3), ('changes', 3), ('major', 3), ('label', 3), ('nominations', 3), ('see', 3), ('10', 3), ('[3', 3), ('no', 3), ('state', 3), ('albany', 3), ('panic', 3), ('disco', 3), ('paramore', 3), ('neon', 3), ('ode', 3), ('lovely', 3), ('save', 3), ('roll', 3), ('2014', 3), ('local', 3), ('beatles', 3), ('hometown', 3), ('jumpsuit', 3), ('nico', 3), ('2018', 3), ('chlorine', 3), ('hype', 3), ('media', 3), ('help', 3), ('[154', 3), ('[160', 3), ('[163', 3), ('[169', 3), ('[182', 3), ('emo', 3), ('singles', 3), ('"episode', 3), ('biography', 3), ('duo', 3), ('interview', 3), ('"founding', 3), ('member', 3), ('opens', 3), ('(moderately', 3), ('inspiring', 3), ('tale', 3), ('longboard', 3), ('rodeo', 3), ('tango', 3), ('episode', 3), ('source', 3), ('know', 3), ('allmusic', 3), ('tracks', 3), ('version', 3), ("'ode", 3), ('more', 3), ('[official', 3), ("'stressed", 3), ('winners', 3), ('announces', 3), ('here', 3), ('have', 3), ('sound', 3), ('cover', 3), ('2017', 3), ("'nico", 3), ("'trench", 3), ('top', 3), ('2019', 3), ('n', 3), ('w', 3), ('l', 3), ('m', 3), ('way', 3), ('news', 3), ('art', 3), ('view', 3), ('jump', 2), ('atlantic', 2), ('annual', 2), ('certification', 2), ('recording', 2), ('industry', 2), ('association', 2), ('2', 2), ('3', 2), ('fandom', 2), ('concert', 2), ('headlining', 2), ('act', 2), ('9', 2), ('school', 2), ('[4', 2), ('[8', 2), ('[9', 2), ('soundcloud', 2), ('emmanuel', 2), ('guitar', 2), ('[26', 2), ('newport', 2), ('hall', 2), ('[31', 2), ('[33', 2), ('[34', 2), ('[35', 2), ('channel', 2), ('[36', 2), ('records', 2), ('trees', 2), ( ...
